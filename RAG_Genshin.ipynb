# %%
# %%writefile requirements.txt
# langchain_community
# langchain
# langchain_google_genai
# loguru
# sentence-transformers==2.3.0
# chromadb
# matplotlib
# jsonargparse
# langchain-openai
# pymupdf
# langchain-core
# langchain-community
# chromadb
# beautifulsoup4
# requests
# python-telegram-bot
# tqdm
# pymupdf
# Out:
# Overwriting requirements.txt

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: langchain_community in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (0.4)
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (1.0.2)
# Requirement already satisfied: langchain_google_genai in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: loguru in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (0.7.3)
# Requirement already satisfied: sentence-transformers==2.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: chromadb in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (1.2.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (3.10.0)
# Requirement already satisfied: jsonargparse in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (4.42.0)
# Requirement already satisfied: langchain-openai in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (1.0.1)
# Requirement already satisfied: pymupdf in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (1.26.5)
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (1.0.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 14)) (4.13.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 15)) (2.32.5)
# Requirement already satisfied: python-telegram-bot in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (22.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (4.67.1)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==2.3.0->-r requirements.txt (line 5)) (4.57.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==2.3.0->-r requirements.txt (line 5)) (2.8.0+cu126)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==2.3.0->-r requirements.txt (line 5)) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==2.3.0->-r requirements.txt (line 5)) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==2.3.0->-r requirements.txt (line 5)) (1.16.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==2.3.0->-r requirements.txt (line 5)) (3.9.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==2.3.0->-r requirements.txt (line 5)) (0.2.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==2.3.0->-r requirements.txt (line 5)) (0.35.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from sentence-transformers==2.3.0->-r requirements.txt (line 5)) (11.3.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community->-r requirements.txt (line 1)) (2.0.44)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community->-r requirements.txt (line 1)) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain_community->-r requirements.txt (line 1)) (3.13.1)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community->-r requirements.txt (line 1)) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /usr/local/lib/python3.12/dist-packages (from langchain_community->-r requirements.txt (line 1)) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain_community->-r requirements.txt (line 1)) (2.11.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain_community->-r requirements.txt (line 1)) (0.4.37)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain_community->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain->-r requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain->-r requirements.txt (line 2)) (2.11.10)
# Requirement already satisfied: google-ai-generativelanguage<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain_google_genai->-r requirements.txt (line 3)) (0.9.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain_google_genai->-r requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 6)) (0.38.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (1.75.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (3.11.3)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.12/dist-packages (from chromadb->-r requirements.txt (line 6)) (4.25.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 7)) (2.9.0.post0)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /usr/local/lib/python3.12/dist-packages (from langchain-openai->-r requirements.txt (line 9)) (1.109.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai->-r requirements.txt (line 9)) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core->-r requirements.txt (line 11)) (1.33)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->-r requirements.txt (line 14)) (2.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 15)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 15)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 15)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 15)) (2025.10.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 1)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 1)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 1)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 1)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community->-r requirements.txt (line 1)) (1.22.0)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community->-r requirements.txt (line 1)) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community->-r requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain_google_genai->-r requirements.txt (line 3)) (2.26.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1.0.0,>=0.7.0->langchain_google_genai->-r requirements.txt (line 3)) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1.0.0,>=0.7.0->langchain_google_genai->-r requirements.txt (line 3)) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from google-ai-generativelanguage<1.0.0,>=0.7.0->langchain_google_genai->-r requirements.txt (line 3)) (5.29.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 6)) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb->-r requirements.txt (line 6)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb->-r requirements.txt (line 6)) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (1.1.10)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core->-r requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb->-r requirements.txt (line 6)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb->-r requirements.txt (line 6)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb->-r requirements.txt (line 6)) (0.27.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (0.10)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.0->langchain->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.0->langchain->-r requirements.txt (line 2)) (1.0.1)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.0->langchain->-r requirements.txt (line 2)) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.0->langchain->-r requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain_community->-r requirements.txt (line 1)) (0.25.0)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 6)) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 6)) (25.9.23)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 6)) (1.13.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai->-r requirements.txt (line 9)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai->-r requirements.txt (line 9)) (0.11.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai->-r requirements.txt (line 9)) (1.3.1)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 6)) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 6)) (1.71.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 6)) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb->-r requirements.txt (line 6)) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk>=1.2.0->chromadb->-r requirements.txt (line 6)) (0.59b0)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from posthog<6.0.0,>=2.4.0->chromadb->-r requirements.txt (line 6)) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r requirements.txt (line 2)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r requirements.txt (line 2)) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb->-r requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb->-r requirements.txt (line 6)) (2.19.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community->-r requirements.txt (line 1)) (3.2.4)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai->-r requirements.txt (line 9)) (2024.11.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (75.2.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (3.4.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (0.6.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb->-r requirements.txt (line 6)) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb->-r requirements.txt (line 6)) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 6)) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb->-r requirements.txt (line 6)) (15.0.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain_google_genai->-r requirements.txt (line 3)) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain_google_genai->-r requirements.txt (line 3)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain_google_genai->-r requirements.txt (line 3)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain_google_genai->-r requirements.txt (line 3)) (4.9.1)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb->-r requirements.txt (line 6)) (3.23.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.0->langchain->-r requirements.txt (line 2)) (1.11.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb->-r requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb->-r requirements.txt (line 6)) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers==2.3.0->-r requirements.txt (line 5)) (3.0.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb->-r requirements.txt (line 6)) (3.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=2.14.1->google-ai-generativelanguage<1.0.0,>=0.7.0->langchain_google_genai->-r requirements.txt (line 3)) (0.6.1)

# %%
import os

# %%
if not os.path.exists("./data"):
  os.mkdir("./data")

# %% [markdown]
# PDF-files preprocessing and chunking

# %%
import fitz
from loguru import logger
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter


def clean_extra_whitespace(text):
    return ' '.join(text.split())


def group_paragraphs(text):
    return text.replace("\n", " ").replace("\r", " ")


def load_pdf(files):
    if not isinstance(files, list):
        files = [files]

    documents = []
    for file_path in files:
        try:
            logger.info(f"Загрузка PDF: {file_path}")
            doc = fitz.open(file_path)
            text = ""

            for page_num in range(len(doc)):
                page = doc.load_page(page_num)
                text += page.get_text("text")

            text = clean_extra_whitespace(text)
            text = group_paragraphs(text)

            document = Document(
                page_content=text,
                metadata={"source": file_path}
            )
            documents.append(document)
            logger.success(f"Успешно загружен: {file_path}")

        except Exception as e:
            logger.error(f"Ошибка загрузки {file_path}: {e}")
            raise

    return documents


def chunk_documents(documents):
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=1200,
        chunk_overlap=150,
        separators=["\n\n## ", "\n\n# ", "\n\n", "\n", ". "]
    )

    chunks = splitter.split_documents(documents)
    analyze_chunk_quality(chunks)
    return chunks


def analyze_chunk_quality(chunks):
    if not chunks:
        return

    chunk_sizes = [len(chunk.page_content) for chunk in chunks]
    avg_size = sum(chunk_sizes) / len(chunk_sizes)

    logger.info("Статистика чанков:")
    logger.info(f"   • Общее количество: {len(chunks)}")
    logger.info(f"   • Средний размер: {avg_size:.0f} символов")
    logger.info(f"   • Минимальный: {min(chunk_sizes)}")
    logger.info(f"   • Максимальный: {max(chunk_sizes)}")

    good_chunks = [c for c in chunks if 200 < len(c.page_content) < 1500]
    quality_ratio = len(good_chunks) / len(chunks)

    logger.info(f"   • Качество: {quality_ratio:.1%} хороших чанков")

# %%
directory = "./data"
files = os.listdir(directory)
pdf_files = [f"{directory}/{file}" for file in files if file.endswith('.pdf')]
print(pdf_files)
documents = load_pdf(files=pdf_files)
chunks = chunk_documents(documents)
analyze_chunk_quality(chunks)
# Out:
# 2025-10-22 18:22:43.748 | INFO     | __main__:load_pdf:22 - Загрузка PDF: ./data/Sinners_Kaenriah.pdf
# 2025-10-22 18:22:43.817 | SUCCESS  | __main__:load_pdf:38 - Успешно загружен: ./data/Sinners_Kaenriah.pdf
# 2025-10-22 18:22:43.819 | INFO     | __main__:load_pdf:22 - Загрузка PDF: ./data/Natlan.pdf
# ['./data/Sinners_Kaenriah.pdf', './data/Natlan.pdf']
# 2025-10-22 18:22:44.173 | SUCCESS  | __main__:load_pdf:38 - Успешно загружен: ./data/Natlan.pdf
# 2025-10-22 18:22:44.191 | INFO     | __main__:analyze_chunk_quality:66 - Статистика чанков:
# 2025-10-22 18:22:44.191 | INFO     | __main__:analyze_chunk_quality:67 -    • Общее количество: 151
# 2025-10-22 18:22:44.193 | INFO     | __main__:analyze_chunk_quality:68 -    • Средний размер: 1122 символов
# 2025-10-22 18:22:44.195 | INFO     | __main__:analyze_chunk_quality:69 -    • Минимальный: 610
# 2025-10-22 18:22:44.196 | INFO     | __main__:analyze_chunk_quality:70 -    • Максимальный: 1199
# 2025-10-22 18:22:44.198 | INFO     | __main__:analyze_chunk_quality:75 -    • Качество: 100.0% хороших чанков
# 2025-10-22 18:22:44.200 | INFO     | __main__:analyze_chunk_quality:66 - Статистика чанков:
# 2025-10-22 18:22:44.204 | INFO     | __main__:analyze_chunk_quality:67 -    • Общее количество: 151
# 2025-10-22 18:22:44.206 | INFO     | __main__:analyze_chunk_quality:68 -    • Средний размер: 1122 символов
# 2025-10-22 18:22:44.208 | INFO     | __main__:analyze_chunk_quality:69 -    • Минимальный: 610
# 2025-10-22 18:22:44.210 | INFO     | __main__:analyze_chunk_quality:70 -    • Максимальный: 1199
# 2025-10-22 18:22:44.213 | INFO     | __main__:analyze_chunk_quality:75 -    • Качество: 100.0% хороших чанков

# %% [markdown]
# Load embedding model and create vectorstore

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma

def load_embedding_model():

    try:
        model_kwargs = {"device": "cpu"}
        encode_kwargs = {"normalize_embeddings": True}

        embedding_model = HuggingFaceEmbeddings(
            model_name='cointegrated/rubert-tiny2',
            model_kwargs=model_kwargs,
            encode_kwargs=encode_kwargs,
        )

        logger.success(f"✅ Модель эмбеддингов загружена: {'cointegrated/rubert-tiny2'}")
        return embedding_model

    except Exception as e:
        logger.error(f"❌ Ошибка загрузки модели: {e}")
        raise


def create_vectorstore(chunks, embedding_model):
        vectorstore = Chroma.from_documents(
            documents=chunks,
            embedding=embedding_model
        )

        return vectorstore

def search_similar(vectorstore, query, k, filter_dict=None):

    results = vectorstore.similarity_search(
        query=query,
        k=k,
        filter=filter_dict
    )

    logger.info(f"Найдено {len(results)} результатов для: '{query}'")
    return results


def retrieve_context(vectorstore, query, k):
    retrieved_docs = search_similar(vectorstore, query, k)
    return retrieved_docs

# %%
embedding_model = load_embedding_model()
vectorstore = create_vectorstore(chunks, embedding_model)
# Out:
# /tmp/ipython-input-1335281124.py:11: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/693 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/118M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/401 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# 2025-10-22 18:23:40.835 | SUCCESS  | __main__:load_embedding_model:17 - ✅ Модель эмбеддингов загружена: cointegrated/rubert-tiny2

# %% [markdown]
# Load LLM Gemini

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from google.colab import userdata

GEMINI_API_KEY = userdata.get('gemini')

def create_gemini_llm():

    try:
        llm = ChatGoogleGenerativeAI(
            model='gemini-flash-latest',
            temperature=0.3,
            max_tokens=3000,
            google_api_key=GEMINI_API_KEY
        )
        logger.success(f"✅ Gemini модель загружена: {'gemini-flash-latest'}")
        return llm
    except Exception as e:
        logger.error(f"❌ Ошибка загрузки Gemini: {e}")
        return None


def create_prompt_template():
    template = """
Ты - эксперт по лору игры Genshin Impact. Ответь на вопрос пользователя на основе предоставленного контекста.

КОНТЕКСТ:
{context}

ВОПРОС:
{question}

ИНСТРУКЦИИ:
- Отвечай ТОЛЬКО на русском языке
- Используй информацию из предоставленного контекста
- Давай полный развернутый ответ
- Если в контексте нет информации, сообщи об этом

ОТВЕТ:
"""
    return ChatPromptTemplate.from_template(template)


def create_chain():
    gemini_llm = create_gemini_llm()

    prompt = create_prompt_template()
    chain = prompt | gemini_llm | StrOutputParser()
    return chain


def generate_response(question, context):

    try:
        chain = create_chain()

        context_text = "\n\n".join([doc.page_content for doc in context])

        response = chain.invoke({
            "context": context_text,
            "question": question
        })

        return response

    except Exception as e:
        logger.error(f"❌ Ошибка генерации ответа: {e}")
        return "Извините, произошла ошибка при генерации ответа."

# %%
question = "Расскажи о героях Каэнри ах"
context = retrieve_context(vectorstore, question, 15)
response = generate_response(question, context)
# Out:
# 2025-10-22 18:26:20.213 | INFO     | __main__:search_similar:41 - Найдено 15 результатов для: 'Расскажи о героях Каэнри ах'
# 2025-10-22 18:26:20.286 | SUCCESS  | __main__:create_gemini_llm:17 - ✅ Gemini модель загружена: gemini-flash-latest

# %%
print(response)
# Out:
# В сюжетном квесте 4.7 «Сказка на ночь» Дайнслейф рассказал о шести «героях» Каэнри'ах, которых в настоящее время прозвали «грешниками».
#
# ### Общая информация о героях
#
# 1.  **Статус и роль:** Все они были великими людьми, лидерами среди своих коллег в различных областях (например, Дайнслейф был лучшим среди мечников, а Рэйндоттир — лучшей среди алхимиков). Королевство Каэнри'ах возлагало на них большие надежды.
# 2.  **Миссия:** Их конкретная миссия состояла в том, чтобы объединиться и предотвратить грядущую катастрофу — помешать некоему «Чёрному королю» продолжать сотрясать основы мира. Предполагается, что они противостояли существу, связанному со скверной.
# 3.  **Падение:** В процессе миссии что-то пошло не так. Пять человек (не считая Дайнслейфа), затаивших в своих сердцах собственные желания, не смогли устоять перед искушением «бездны» и разделили силу, которой было достаточно, чтобы уничтожить мир.
#
# ### Известные «Герои»/«Грешники»
#
# В контексте упоминаются четыре грешника, а также Дайнслейф, который не поддался искушению:
#
# **1. Ведрфёльнир («Провидец»)**
# *   **Личность:** Кровный старший брат Дайнслейфа. Чистокровный каэнри'ец.
# *   **Роль:** Специализируется на пророчествах, прошлом, будущем и судьбе. Он словно сценарист или кукловод, знающий прошлое и предсказывающий будущее, влияющий на события для достижения своей цели.
# *   **Действия:** Он повлиял на возникновение плана «Плетение судьбы» и сподвиг Клотара Альбериха (основателя Ордена Бездны) на создание Ордена. Он также явился перед Близнецом Бездны, посеяв сомнения, которые привели к тому, что Близнец возглавил Орден.
# *   **Пророчества:** Ему приписывают создание каменных плит с пророчеством Фонтейна. На плитах была надпись: «Это государство должно быть стёрто с лица земли. Я запишу историю его будущего в прошлом...»
# *   **Способности:** Он смог говорить напрямую в голове Близнеца Бездны, что является довольно интересной способностью.
#
# **2. Сурталоги («Скверный рыцарь»)**
# *   **Роль:** Наставник Скирк и хозяин Всепожирающего нарвала.
# *   **Сила:** По словам Скирк, даже если Тейват будет уничтожен, нарвал (его питомец) выживет и сможет уплыть к другим мирам, чтобы испить их Первозданную воду и уничтожить планету.
# *   **Связь с судьбой:** Вероятно, он является «ангелом заката в конце времён», упомянутым в босс-теме Нарвала. Это отсылает к скандинавской мифологии (Сурт и Рагнарёк), предполагая, что ему суждено сразить богов и запечатлеть закат их правления.
#
# **3. Рэйндоттир (Рейн)**
# *   **Связь:** Она является одной из пяти грешников.
# *   **Отношения:** Несмотря на статус «грешницы», в её взаимоотношениях с Алисой (ведьмой Шабаша) прослеживается теплота и поддержка, что говорит о том, что другие ведьмы от неё не отвернулись.
# *   **Творчество:** В книге «Влюблённый Хлеоланд» упоминается, что волк «Чёрная тень», неразлучный с Ньёрдом, был создан Рэйндоттир.
#
# **4. Рери («Лунный мститель»)**
# *   **Титул:** «Лунный охотник» или «Человек, охотящийся на луну».
# *   **Подробности:** Лорных подробностей о нём в контексте нет. Его имя этимологически отсылает к немецкому слову «Rächer», что означает «мститель».
#
# **5. Дайнслейф**
# *   Он является шестым героем, но не входит в число пяти, которые поддались искушению Бездны.
#
# **6. Пятый грешник**
# *   Имя пятого грешника, который поддался искушению Бездны, в предоставленном контексте не названо.
#
# ### Исторические предшественники
#
# Существует предположение, что подобный отбор сильнейших и возведение их в ранг «героев» всегда существовал в Каэнри'ах, и наша шестёрка — не первое поколение.
#
# Книга «Влюблённый Хлеоланд» (которая точна в ключевых подробностях, несмотря на вымышленный сюжет) рассказывает о предшествующей династии Алой Луны. В ту династию также выделялись сильней
